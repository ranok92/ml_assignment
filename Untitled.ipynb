# %%
#quesiton 1.a
import numpy as np

from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,
                                              ExpSineSquared, DotProduct,
                                              ConstantKernel)


kernels = [1 * RBF(length_scale=1, length_scale_bounds=(1e-1, 10.0))]

for fig_index, kernel in enumerate(kernels):
    # Specify Gaussian Process
    gp = GaussianProcessRegressor(kernel=kernel)

    # Plot prior
    plt.figure(fig_index, figsize=(8, 8))
    plt.subplot(2, 1, 1)
    X_ = np.linspace(0, 5, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')
    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.xlim(0, 5)
    plt.ylim(-3, 3)
    plt.title("Prior (kernel:  %s)" % kernel, fontsize=12)

    # Generate data and fit GP
    
    plt.tight_layout()

plt.show()

# %%
#question 1.c
import numpy as np

from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,
                                              ExpSineSquared, DotProduct,
                                              ConstantKernel)


kernels = [1.1 * RBF(length_scale=0.1, length_scale_bounds=(1e-3, 1)),
           ConstantKernel(0.1, (0.01, 10.0))*(DotProduct(sigma_0=1.0, sigma_0_bounds=(0.0, 10.0)) ** 2),
           (RationalQuadratic(length_scale = 0.1)),
          1.1 * RBF(length_scale=0.1, length_scale_bounds=(1e-3, 1))+(RationalQuadratic(length_scale = 0.1))]

for fig_index, kernel in enumerate(kernels):
    # Specify Gaussian Process
    gp = GaussianProcessRegressor(kernel=kernel)

    # Plot prior
    plt.figure(fig_index, figsize=(8, 8))
    plt.subplot(2, 1, 1)
    X_ = np.linspace(0, 15, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')
    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.xlim(0, 15)
    plt.ylim(-3, 3)
    plt.title("Prior (kernel:  %s)" % kernel, fontsize=12)

    # Generate data and fit GP
    rng = np.random.RandomState(4)
    X = rng.uniform(0, 10, 50)[:, np.newaxis]
    y = X[:,0]*np.sin((X[:, 0]))
    gp.fit(X, y)

    # Plot posterior
    plt.subplot(2, 1, 2)
    X_ = np.linspace(0, 15, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')

    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.scatter(X[:, 0], y, c='r', s=50, zorder=10, edgecolors=(0, 0, 0))
    plt.xlim(0, 15)
    plt.ylim(-5, 5)
    plt.title("Posterior (kernel: %s)\n Log-Likelihood: %.3f"
              % (gp.kernel_, gp.log_marginal_likelihood(gp.kernel_.theta)),
              fontsize=12)
    plt.tight_layout()

plt.show()
# Out:
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:335: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\kernels.py:288: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.vstack(bounds))
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.85116863,  0.4637808 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 120, 'nit': 21, 'warnflag': 2}
#   " state: %s" % convergence_dict)

# %%
#question 1.d

import numpy as np

from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,
                                              ExpSineSquared, DotProduct,
                                              ConstantKernel)


kernels = [1.1 * RBF(length_scale=0.1, length_scale_bounds=(1e-3, 1)),
           ConstantKernel(0.1, (0.01, 10.0))*(DotProduct(sigma_0=1.0, sigma_0_bounds=(0.0, 10.0)) ** 2),
           (RationalQuadratic(length_scale = 0.1)),
          1.1 * RBF(length_scale=0.1, length_scale_bounds=(1e-3, 1))+(RationalQuadratic(length_scale = 0.1))]

for fig_index, kernel in enumerate(kernels):
    # Specify Gaussian Process
    gp = GaussianProcessRegressor(kernel=kernel)

    # Plot prior
    plt.figure(fig_index, figsize=(8, 8))
    plt.subplot(2, 1, 1)
    X_ = np.linspace(0, 15, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')
    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.xlim(0, 15)
    plt.ylim(-3, 3)
    plt.title("Prior (kernel:  %s)" % kernel, fontsize=12)

    # Generate data and fit GP
    rng = np.random.RandomState(4)
    X = rng.uniform(0, 10, 50)[:, np.newaxis]
    y = X[:,0]*np.sin((X[:, 0]))+np.random.normal(0,0.5,(50))
    gp.fit(X, y)

    # Plot posterior
    plt.subplot(2, 1, 2)
    X_ = np.linspace(0, 15, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')

    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.scatter(X[:, 0], y, c='r', s=50, zorder=10, edgecolors=(0, 0, 0))
    plt.xlim(0, 15)
    plt.ylim(-5, 5)
    plt.title("Posterior (kernel: %s)\n Log-Likelihood: %.3f"
              % (gp.kernel_, gp.log_marginal_likelihood(gp.kernel_.theta)),
              fontsize=12)
    plt.tight_layout()

plt.show()
# Out:
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\kernels.py:288: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.vstack(bounds))
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:335: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "

# %%
np.random.normal(0,0.5,(50,0))
# Out:
# array([], shape=(50, 0), dtype=float64)

# %%
p = np.random.normal(0,0.5,(50,0))

# %%
p
# Out:
# array([], shape=(50, 0), dtype=float64)

# %%
y = X[:,0]*np.sin((X[:, 0]))

# %%
y
# Out:
# array([ -2.35047414e+00,  -3.96678706e+00,  -2.89366745e+00,
#          5.44031304e+00,   4.46334471e+00,   1.79545694e+00,
#         -3.23702730e+00,   3.87909733e-03,   1.45291956e+00,
#         -4.06230733e+00,   7.77973321e+00,   1.81610595e+00,
#          6.15966147e+00,  -3.91297033e+00,   1.63467735e+00,
#         -1.82134196e+00,   8.06413192e-03,  -2.56094443e+00,
#          1.88734367e-01,  -1.35153518e+00,  -4.09566120e+00,
#         -6.16354651e-01,   7.86273585e+00,   5.97987824e+00,
#          1.70929898e+00,   5.10596608e-01,  -1.63568106e+00,
#          1.66976693e+00,   6.36375788e+00,  -3.30526387e+00,
#         -4.45384836e+00,   4.59807989e-01,  -4.56683054e+00,
#          9.55204351e-01,   1.58213058e+00,  -4.02748240e+00,
#         -4.52021027e+00,   5.91597039e-01,  -3.07743198e+00,
#          1.38549041e+00,  -2.92189524e+00,  -2.74585184e-01,
#          7.55015882e+00,   1.74701377e+00,  -2.16435430e+00,
# ...

# %%
p = np.random.normal(0,0.5,50)

# %%
p
# Out:
# array([ 0.46290441,  0.44415853, -0.30440414,  0.21192917,  0.22662844,
#        -0.24415894,  0.07774597,  0.25019   , -0.86866809,  0.50910338,
#         0.57630305, -0.39065325,  0.43489311,  0.39565397, -0.05034085,
#         0.1434314 ,  0.52196536, -0.34064829,  0.09413155, -0.32329591,
#         0.31088788,  0.24970275, -0.06766616,  0.21963219,  0.77398002,
#        -0.88267374, -0.15112394,  0.16929537,  0.78092538,  0.24309095,
#         0.79357859, -0.03599259,  0.22819929,  0.29953012, -0.60771594,
#        -0.18052837,  0.30606101,  0.30751682, -0.11269118, -0.17829716,
#        -0.26909817, -0.21353499, -0.80003615,  0.62755823,  0.17983486,
#        -0.15398084, -0.2620252 , -0.99999289, -0.24888998,  0.03335142])

# %%
#question 1.d.2

import numpy as np

from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, WhiteKernel , RationalQuadratic,
                                              DotProduct)


kernels = [1.1 * RBF(length_scale=0.1, length_scale_bounds=(1e-3, 1)),
           ConstantKernel(0.1, (0.01, 10.0))*(DotProduct(sigma_0=1.0, sigma_0_bounds=(0.0, 10.0)) ** 2),
           (RationalQuadratic(length_scale = 0.1)),
          1.1 * RBF(length_scale=0.1, length_scale_bounds=(1e-3, 1))+(RationalQuadratic(length_scale = 0.1))]

for fig_index, kernel in enumerate(kernels):
    # Specify Gaussian Process
    kernel_new = kernel+ WhiteKernel(1)
    gp = GaussianProcessRegressor(kernel=kernel)

    # Plot prior
    plt.figure(fig_index, figsize=(8, 8))
    plt.subplot(2, 1, 1)
    X_ = np.linspace(0, 15, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')
    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.xlim(0, 15)
    plt.ylim(-3, 3)
    plt.title("Prior (kernel:  %s)" % kernel, fontsize=12)

    # Generate data and fit GP
    rng = np.random.RandomState(4)
    X = rng.uniform(0, 10, 50)[:, np.newaxis]
    y = X[:,0]*np.sin((X[:, 0]))+np.random.normal(0,0.5,(50))
    gp.fit(X, y)

    # Plot posterior
    plt.subplot(2, 1, 2)
    X_ = np.linspace(0, 15, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')

    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.scatter(X[:, 0], y, c='r', s=50, zorder=10, edgecolors=(0, 0, 0))
    plt.xlim(0, 15)
    plt.ylim(-5, 5)
    plt.title("Posterior (kernel: %s)\n Log-Likelihood: %.3f"
              % (gp.kernel_, gp.log_marginal_likelihood(gp.kernel_.theta)),
              fontsize=12)
    plt.tight_layout()

plt.show()
# Out:
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\kernels.py:288: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.vstack(bounds))
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:457: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([ -1.09104333e+09,   2.42155520e+08]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 57, 'nit': 2, 'warnflag': 2}
#   " state: %s" % convergence_dict)
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:335: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "

# %%
import pandas as pd
from sklearn import preprocessing
df = pd.read_csv('mauna.csv', header = 0)


df_centered = preprocessing.scale(df,with_mean = 'True' , with_std = 'False')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-2a51c459bc27> in <module>()
#       4
#       5
# ----> 6 df_centered = preprocessing.scale(df,with_mean = 'True' , with_std = 'False')
#
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# C:\Users\Abhisek\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
# ...

# %%
df = df.drop(df.columns[0], axis=1)

# %%
# Out:
#      trainCO2  trainyear  testCO2  testyear
# 0      315.71     1958.2   377.03    2004.0
# 1      317.45     1958.3   377.82    2004.1
# 2      317.50     1958.4   378.75    2004.2
# 3      315.86     1958.5   380.42    2004.3
# 4      314.93     1958.6   380.65    2004.4
# 5      313.20     1958.7   379.53    2004.5
# 6      313.33     1958.9   377.61    2004.5
# 7      314.67     1959.0   376.51    2004.6
# 8      315.62     1959.0   374.28    2004.7
# 9      316.38     1959.1   374.46    2004.8
# 10     316.71     1959.2   375.96    2004.9
# 11     317.72     1959.3   377.45    2005.0
# 12     318.29     1959.4   378.46    2005.0
# 13     318.16     1959.5   379.74    2005.1
# 14     316.55     1959.5   381.04    2005.2
# 15     314.80     1959.6   382.19    2005.3
# 16     313.84     1959.7   382.44    2005.4
# 17     313.26     1959.8   382.16    2005.5
# 18     314.80     1959.9   380.75    2005.5
# 19     315.59     1960.0   378.71    2005.6
# ...
